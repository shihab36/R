# %%
df = read.csv("data.csv")

# %%
person = c(10,10,5,5,10)
sports = c("Badmintion","Cricket","Volyball","Football","Hokey")

# %%
barplot(person, names.arg = sports, main = "Student Favorite Sports", xlab = "Sports", ylab = "Frequency", horiz = TRUE)
# Out:
# Plot with title "Student Favorite Sports"

# %%
str(df)
# Out:
# 'data.frame':	36 obs. of  5 variables:
#  $ Car   : chr  "Toyoty" "Mitsubishi" "Skoda" "Fiat" ...
#  $ Model : chr  "Aygo" "Space Star" "Citigo" "500" ...
#  $ Volume: int  1000 1200 1000 900 1500 1000 1400 1500 1500 1600 ...
#  $ Weight: int  790 1160 929 865 1140 929 1109 1365 1112 1150 ...
#  $ CO2   : int  99 95 95 90 105 105 90 92 98 99 ...

# %%
hist(df$CO2, xlab = "CO2", main = "Histogram of CO2 Emmissions of Car")
# Out:
# Plot with title "Histogram of CO2 Emmissions of Car"

# %%
barplot(df$Volume, names.arg = df$Car)
# Out:
# plot without title
